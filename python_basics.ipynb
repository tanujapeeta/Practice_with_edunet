# %%
q1=50000
q2=75000
q3=60000
q4=65000
total_profit=q1+q2+q3+q4
print(total_profit)
# Out:
# 250000

# %%
del len

# %%
pwd="secure@123"
len=len(pwd)
if len>=8:
  print("lenght is 8 characters")
# Out:
# lenght is 8 characters

# %%
nb_price=45
no_of_nb=8
amount=500
change=amount-(nb_price*no_of_nb)
print("change:",change)
# Out:
# change: 140

# %%
from re import X
x=str(30)
y=int(3)
z=float(3)
print(type(x))
print(type(y))
print(type(z))
# Out:
# <class 'str'>
# <class 'int'>
# <class 'float'>

# %%
x="awesome"
def myfun():
  y="Tanuja"
  print("python is",x)
  print("My name is",y)
myfun()
print("python is",x)
print("My name is",y)
# Out:
# python is awesome
# My name is Tanuja
# python is awesome
# My name is 3

# %%
def myfun():
  global x
  x="fantastic"
myfun()
print("python is",x)
# Out:
# python is fantastic

# %%
a="Hello World"
b=20
c=20.5
d=["apple","banana","cherry"]
e=("apple","banana","cherry")
f=True
print(type(a))
print(type(b))
print(type(c))
print(type(d))
print(type(e))
print(type(f))
# Out:
# <class 'str'>
# <class 'int'>
# <class 'float'>
# <class 'list'>
# <class 'tuple'>
# <class 'bool'>

# %%
A="Welcome to Edunet"
a="Sneha"
b="TSP 4.0"
print(A)
print(a)
print(b)
# Out:
# Welcome to Edunet
# Sneha
# TSP 4.0

# %%
a="Hello World!"
print(a[1])
# Out:
# e

# %%
for x in "Bnanan":
  print(x)
# Out:
# B
# n
# a
# n
# a
# n

# %%
x=1
y=2.8
z=1j
print(type(x))
print(type(y))
print(type(z))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'complex'>

# %%
x=1
y=2.5
z=1j
a=float(x)
b=int(y)
c=complex(x)
print(a)
print(b)
print(c)
print(type(a))
print(type(b))
print(type(c))
# Out:
# 1.0
# 2
# (1+0j)
# <class 'float'>
# <class 'int'>
# <class 'complex'>

# %%
li=[1,2,'mango',"R",5,True,3+2j]
tup=[1,2,'mango',"R",5,True,3+2j]
dict={1:'one',2:'two',3:'three'}
set={'a','b','c','d','e','f'}
print(type(li))
print(type(tup))
print(type(dict))
print(type(set))
# Out:
# <class 'list'>
# <class 'list'>
# <class 'dict'>
# <class 'set'>

# %%
a=True
b=False
c=None
print(type(a))
print(type(b))
print(type(c))
# Out:
# <class 'bool'>
# <class 'bool'>
# <class 'NoneType'>
